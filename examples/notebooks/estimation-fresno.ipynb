# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import numpy as np
import pandas as pd
import random
import tensorflow as tf
import isuelogit as isl
import glob
import time

# %%
# Path management
main_dir = str(Path(os.path.abspath('')).parents[1])
os.chdir(main_dir)
print('main dir:', main_dir)

isl.config.dirs['read_network_data'] = "input/network-data/fresno/"
# Out:
# main dir: /Users/pablo/github/pesuelogit

# %%
# Internal modules
from src.pesuelogit.models import UtilityParameters, BPRParameters, ODParameters, PESUELOGIT
from src.pesuelogit.visualizations import plot_predictive_performance, plot_convergence_estimates, plot_top_od_flows_periods, plot_utility_parameters_periods, plot_rr_by_period, plot_rr_by_period_models, plot_total_trips_models
from src.pesuelogit.networks import load_k_shortest_paths, read_paths, build_fresno_network, \
    Equilibrator, sparsify_OD, ColumnGenerator, read_OD
from src.pesuelogit.etl import data_curation, add_period_id, get_tensors_by_year
from src.pesuelogit.descriptive_statistics import nrmse, mape, mse

# %%
# Seed for reproducibility
_SEED = 2023
np.random.seed(_SEED)
random.seed(_SEED)
tf.random.set_seed(_SEED)

# %%
# To report global runtime
t0_global = time.time()

# %% [markdown]
# ## Build Fresno network

# %%
fresno_network = build_fresno_network()

# %% [markdown]
# ## Read OD matrix

# %%
read_OD(network=fresno_network, sparse=True)
# Out:
# Matrix Q (1789, 1789) read in 0.0[s] with sparse format
# 66266.3 trips were loaded among 6970 o-d pairs

# %% [markdown]
# ## Read paths

# %%
#read_paths(network=fresno_network, update_incidence_matrices=True, filename='paths-fresno.csv')
read_paths(network=fresno_network, update_incidence_matrices=True, filename = 'paths-full-model-fresno.csv')

# For quick testing
# Q = fresno_network.load_OD(sparsify_OD(fresno_network.Q, prop_od_pairs=0.99))
# load_k_shortest_paths(network=fresno_network, k=2, update_incidence_matrices=True)
# Out:
# 18289 paths were read in 6.6[s]
#
# 18289 paths were loaded in the network
#
# Updating incidence matrices
#
# Matrix D (2413, 18289) generated in 6.1[s]
#
# Matrix M (6970, 18289) generated in 2.2[s]
#
# Matrix C (18289, 18289) generated in 1.0[s]

# %% [markdown]
# ## Read spatiotemporal data

# %%
folderpath = isl.config.dirs['read_network_data'] + 'links/spatiotemporal-data/'
df = pd.concat([pd.read_csv(file) for file in glob.glob(folderpath + "*link-data*")], axis=0)

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
# Select data from Tuesday to Thursday
df = df[df['date'].dt.dayofweek.between(1, 3)]
# df = df[df['date'].dt.year == 2019]
# Select data from Wednesday only
#df = df[df['date'].dt.dayofweek.between(2, 2)]

# Select data from one day only
#df = df[df['date'] == "2019-10-02"]

# %%
# Add period id for timevarying estimation

period_feature = 'hour'

df['period'] = df['date'].astype(str) + '-' + df[period_feature].astype(str)
# df['period'] = df.period.map(hash)

df = add_period_id(df, period_feature='hour')

period_keys = df[[period_feature,'period_id']].drop_duplicates().reset_index().drop('index',axis =1).sort_values('hour')
print(period_keys)
# Out:
#     hour  period_id
# 11     6          0
# 12     7          1
# 13     8          2
# 14     9          3
# 0     10          4
# 1     11          5
# 2     12          6
# 3     13          7
# 4     14          8
# 5     15          9
# 6     16         10
# 7     17         11
# 8     18         12
# 9     19         13
# 10    20         14

# %%
df.head()
# Out:
#             link_key  observed  counts  capacity [veh]  tt_ff [min]  \
# 0     (0, 1621, '0')         0     NaN          1800.0        0.098
# 1  (1239, 1630, '0')         0     NaN             inf        0.000
# 2    (228, 192, '0')         1  1667.0          2400.0        0.110
# 3  (1243, 1631, '0')         0     NaN             inf        0.000
# 4  (1244, 1632, '0')         0     NaN             inf        0.000
#
#    speed_ff[mi/hr]      inrix_id  pems_ids link_type   id  ...  median_age  \
# 0               45  1.626616e+09        []     LWRLK    1  ...        31.1
# 1            99999           NaN        []     DMDLK  565  ...         0.0
# 2               65  1.626659e+09  [602350]     LWRLK  564  ...        16.6
# 3            99999           NaN        []     DMDLK  563  ...         0.0
# 4            99999           NaN        []     DMDLK  562  ...         0.0
#
#    incidents  bus_stops  intersections       date  hour  tf_inrix  year  \
# 0          0          0              1 2019-10-01    10     0.221  2019
# 1          0          0              0 2019-10-01    10     0.000  2019
# 2          0          0              0 2019-10-01    10     0.112  2019
# 3          0          0              0 2019-10-01    10     0.000  2019
# 4          0          0              0 2019-10-01    10     0.000  2019
#
#           period  period_id
# 0  2019-10-01-10          4
# 1  2019-10-01-10          4
# 2  2019-10-01-10          4
# 3  2019-10-01-10          4
# 4  2019-10-01-10          4
#
# [5 rows x 43 columns]

# %%
# Units in miles per hour
df[['speed_ref_avg','speed_hist_avg','speed_max']].describe()
# Out:
#        speed_ref_avg  speed_hist_avg     speed_max
# count   1.013460e+06    1.009583e+06  1.013460e+06
# mean    1.924470e+01    1.767589e+01  2.051278e+01
# std     1.982261e+01    1.909664e+01  2.140424e+01
# min     0.000000e+00    0.000000e+00  0.000000e+00
# 25%     0.000000e+00    0.000000e+00  0.000000e+00
# 50%     2.112700e+01    1.755400e+01  2.112700e+01
# 75%     2.796200e+01    2.547600e+01  3.106900e+01
# max     6.772900e+01    7.891400e+01  8.388500e+01

# %%
df.columns
# Out:
# Index(['link_key', 'observed', 'counts', 'capacity [veh]', 'tt_ff [min]',
#        'speed_ff[mi/hr]', 'inrix_id', 'pems_ids', 'link_type', 'id', 'rhoj',
#        'lane', 'ff_speed', 'length', 'alpha', 'beta', 'tf', 'k', 'inrix_id.1',
#        'speed_avg', 'speed_ref_avg', 'speed_hist_avg', 'tt_avg', 'speed_max',
#        'speed_sd', 'speed_cv', 'speed_hist_sd', 'speed_ref_sd', 'tt_sd',
#        'tt_var', 'tt_cv', 'road_closures', 'median_inc', 'median_age',
#        'incidents', 'bus_stops', 'intersections', 'date', 'hour', 'tf_inrix',
#        'year', 'period', 'period_id'],
#       dtype='object')

# %% [markdown]
# ## Data curation

# %%
df['tt_ff'] = np.where(df['link_type'] != 'LWRLK', 0,df['length']/df['speed_ref_avg'])
df.loc[(df.link_type == "LWRLK") & (df.speed_ref_avg == 0),'tt_ff'] = float('nan')

df['tt_avg'] = np.where(df['link_type'] != 'LWRLK', 0,df['length']/df['speed_hist_avg'])
df.loc[(df.link_type == "LWRLK") & (df.speed_hist_avg == 0),'tt_avg'] = float('nan')

tt_sd_adj = df.groupby(['period_id','link_key'])[['tt_avg']].std().reset_index().rename(columns = {'tt_avg': 'tt_sd_adj'})

df = df.merge(tt_sd_adj, on = ['period_id','link_key'])

df = data_curation(df)

df['tt_sd'] = df['tt_sd_adj']

# %%
# Units of travel time features are converted from hours to minutes
df['tt_sd'] = df['tt_sd']*60
df['tt_avg'] = df['tt_avg']*60
df['tt_ff'] = df['tt_ff']*60

# %%
df[['speed_ref_avg','speed_hist_avg', 'tt_ff', 'tt_avg','tt_sd_adj']].describe()
# Out:
#        speed_ref_avg  speed_hist_avg         tt_ff         tt_avg  \
# count   1.013460e+06    1.009583e+06  1.013460e+06  887813.000000
# mean    1.924470e+01    1.767589e+01  2.038423e-01       0.219493
# std     1.982261e+01    1.909664e+01  2.610045e-01       0.262030
# min     0.000000e+00    0.000000e+00  0.000000e+00       0.000000
# 25%     0.000000e+00    0.000000e+00  0.000000e+00       0.000000
# 50%     2.112700e+01    1.755400e+01  1.497376e-01       0.167050
# 75%     2.796200e+01    2.547600e+01  2.792397e-01       0.312986
# max     6.772900e+01    7.891400e+01  4.220601e+00       3.827439
#
#           tt_sd_adj
# count  1.013460e+06
# mean   3.022799e-04
# std    4.638521e-04
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.856268e-04
# 75%    4.248116e-04
# max    1.243267e-02

# %% [markdown]
# ## Utility function

# %%
# features_Z = ['tt_sd', 'median_inc', 'incidents', 'bus_stops', 'intersections']
features_Z = ['tt_sd', 'median_inc', 'incidents', 'bus_stops', 'intersections']
# features_Z = ['speed_sd', 'median_inc', 'incidents', 'bus_stops', 'intersections']

#df['tt_sd'] = 0

utility_parameters = UtilityParameters(features_Y=['tt'],
                                       features_Z=features_Z,
                                       initial_values={'tt': 0, 'c': 0, 's': 0, 'psc_factor': 0,
                                                       'fixed_effect': np.zeros_like(fresno_network.links)},
                                       signs={'tt': '-', 'tt_sd': '-', 'median_inc': '+', 'incidents': '-',
                                              'bus_stops': '-', 'intersections': '-'},
                                       trainables={'psc_factor': False, 'fixed_effect': False},
                                       )

utility_parameters.constant_initializer(0)

# %% [markdown]
# ## Data processing

# %%
n_links = len(fresno_network.links)
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['year'] = df.date.dt.year
X, Y = {}, {}

# %%
df.query('year == 2019')[['counts', 'tt_ff', 'tt_avg', 'tf_inrix', 'tt_sd']].describe()
# Out:
#              counts          tt_ff         tt_avg       tf_inrix  \
# count  31624.000000  542925.000000  468303.000000  542925.000000
# mean    1761.140959       0.204903       0.221931       0.200169
# std      770.228931       0.262226       0.266852       0.228208
# min        1.000000       0.000000       0.000000       0.000000
# 25%     1249.000000       0.000000       0.000000       0.000000
# 50%     1686.000000       0.150455       0.168820       0.152000
# 75%     2162.450000       0.282111       0.318261       0.280000
# max     4807.000000       4.220601       3.827439       2.302000
#
#                tt_sd
# count  542925.000000
# mean        0.018137
# std         0.027831
# min         0.000000
# 25%         0.000000
# 50%         0.011138
# 75%         0.025489
# max         0.745960

# %%
df.query('year == 2020')[['counts', 'tt_ff', 'tt_avg', 'tf_inrix', 'tt_sd']].describe()
# Out:
#              counts          tt_ff         tt_avg       tf_inrix  \
# count  27472.000000  470535.000000  419510.000000  470535.000000
# mean    1605.127777       0.202618       0.216770       0.198494
# std      743.713869       0.259583       0.256512       0.226003
# min        6.000000       0.000000       0.000000       0.000000
# 25%     1108.450000       0.000000       0.000000       0.000000
# 50%     1528.900000       0.149437       0.165341       0.150000
# 75%     1978.000000       0.274658       0.306717       0.273000
# max     4766.000000       4.220601       3.274444       2.113000
#
#                tt_sd
# count  470535.000000
# mean        0.018137
# std         0.027831
# min         0.000000
# 25%         0.000000
# 50%         0.011138
# 75%         0.025489
# max         0.745960

# %%
# Set free flow travel times
tt_ff_links = df.groupby('link_key')['tt_ff'].min()
for link in fresno_network.links:
    fresno_network.links_dict[link.key].performance_function.tf = float(tt_ff_links[tt_ff_links.index==str(link.key)])

# %%
# This correlation should be positive
df[['counts','tt_avg']].corr()
# Out:
#           counts    tt_avg
# counts  1.000000  0.055122
# tt_avg  0.055122  1.000000

# %% [markdown]
# ## EDA

# %%
# To check that there is a balanced amount of observations per date
obs_date = df.groupby('date')['hour'].count()

# %%
# Stats by date
df.groupby('date')[['speed_sd','speed_avg', 'counts']].mean().assign(total_obs = obs_date)
# Out:
#             speed_sd  speed_avg       counts  total_obs
# date
# 2019-10-01  1.731787  17.175187  1770.335035      36195
# 2019-10-02  1.760109  17.169768  1746.651824      36195
# 2019-10-03  1.754288  17.092304  1785.115209      36195
# 2019-10-08  1.847060  18.165569  1747.732955      36195
# 2019-10-09  1.917923  18.137042  1756.834846      36195
# 2019-10-10  1.830232  18.107925  1793.512340      36195
# 2019-10-15  1.831527  18.114384  1750.339155      36195
# 2019-10-16  1.823680  18.162625  1760.170975      36195
# 2019-10-17  1.832219  18.080860  1775.411385      36195
# 2019-10-22  1.837839  18.175561  1738.314834      36195
# 2019-10-23  1.864443  18.222690  1753.243283      36195
# 2019-10-24  1.848827  18.184814  1746.626881      36195
# 2019-10-29  1.868430  18.167171  1731.246241      36195
# 2019-10-30  1.816364  18.109232  1757.581055      36195
# 2019-10-31  1.882446  18.128430  1804.595108      36195
# 2020-10-01  1.290377  19.579215  1616.266052      36195
# 2020-10-06  1.365919  19.709670  1581.200095      36195
# 2020-10-07  1.327017  19.927088  1587.425957      36195
# 2020-10-08  1.344382  19.969943  1604.360618      36195
# 2020-10-13  1.311842  19.626350  1607.663262      36195
# 2020-10-14  1.300075  19.558364  1613.399054      36195
# 2020-10-15  1.331493  19.621633  1637.123641      36195
# 2020-10-20  1.353743  19.597736  1599.044113      36195
# 2020-10-21  1.325694  19.501768  1587.235083      36195
# 2020-10-22  1.334320  19.591921  1628.075697      36195
# 2020-10-27  1.309348  19.573460  1583.478061      36195
# 2020-10-28  1.324270  19.646064  1593.821986      36195
# 2020-10-29  1.336212  19.557279  1627.548269      36195

# %% [markdown]
# ### Link attributes

# %%
df[features_Z].describe()
# Out:
#               tt_sd    median_inc     incidents     bus_stops  intersections
# count  1.013460e+06  1.013460e+06  1.013460e+06  1.013460e+06   1.013460e+06
# mean   1.813680e-02  2.621913e+01  7.441093e-01  1.500207e-01   8.765023e-01
# std    2.783112e-02  2.135738e+01  3.193143e+00  4.411927e-01   1.319496e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    1.113761e-02  2.482100e+01  0.000000e+00  0.000000e+00   0.000000e+00
# 75%    2.548870e-02  4.168100e+01  0.000000e+00  0.000000e+00   1.000000e+00
# max    7.459602e-01  1.158930e+02  4.000000e+01  4.000000e+00   9.000000e+00

# %% [markdown]
# ## Training and validation sets

# %%
# Data between 4pm and 5pm to estimate LUE, ODLUE and ODLULPE models
X, Y = get_tensors_by_year(df[df.hour.isin([16])], features_Z = features_Z, network = fresno_network)

# Hourly data DURING morning and afternoon peak hour windows (6 hour intervals) to estimate TVODLULPE
XT, YT = get_tensors_by_year(df[df.hour.isin([6,7,8, 15,16,17])], features_Z = features_Z, network = fresno_network)

# Split in training and test sets
# X_train, X_test, Y_train, Y_test = X[2019], X[2020], Y[2019], Y[2020]
# XT_train, XT_test, YT_train, YT_test = XT[2019], XT[2020], YT[2019], YT[2020]
# X_test, Y_test = None, None
# XT_test, YT_test = None, None
X_train, X_test, Y_train, Y_test = X[2019], None, Y[2019], None
XT_train, XT_test, YT_train, YT_test = XT[2019], None, YT[2019], None
X_test, Y_test = None, None
XT_test, YT_test = None, None

# %% [markdown]
# ## Configuration

# %%
# For testing
#_EPOCHS = {'learning': 4, 'equilibrium': 2}
# _EPOCHS = {'learning': 10, 'equilibrium': 5}
_EPOCHS = {'learning': 300, 'equilibrium': 100}
# _BATCH_SIZE = 16
_BATCH_SIZE = None
_LR = 5e-1
_RELATIVE_GAP = 2e-2
#_RELATIVE_GAP = 1e-5
_XTICKS_SPACING = 50
_EPOCHS_PRINT_INTERVAL = 10

# When adding fixed effects, all parameters of the utility function are idenfiable but provided that the utility coefficients are period specific. The
# only attribute that is always identifiable is the standard deviation of travel time because it changes over hours for same link. Overall, removing fixed effect ease the identification of the parameters of the utility function.
_FIXED_EFFECT = False
# features_Z = ['tt_sd']

# Excluding historic OD gives more freedom for the model to find an equilibria and minimize reconstruction error
_LOSS_WEIGHTS ={'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 3, 'ntrips': 0, 'prop_od': 0}
# _LOSS_WEIGHTS ={'od': 0, 'tt': 1e-2, 'flow': 1, 'eq_flow': 1e-3, 'ntrips': 0, 'prop_od': 0}
# _LOSS_WEIGHTS ={'od': 0, 'tt': 1e-1, 'flow': 1, 'eq_flow': 4, 'ntrips': 0, 'prop_od': 0}
#_LOSS_WEIGHTS ={'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 1, 'ntrips': 1, 'prop_od': 1}

# _LOSS_METRIC  = mnrmse
# _MOMENTUM_EQUILIBRIUM = {'lue': 0.95, 'odlue': 0.95, 'odlulpe': 0.95, 'tvodlulpe':0.95}

# NRMSE encourages a larger reduction in link flow loss and it does not requires to add much momentum to the equilibrium loss component
_LOSS_METRIC  = nrmse
#_LOSS_METRIC  = mse
_MOMENTUM_EQUILIBRIUM = {'lue': 1, 'odlue': 1, 'odlulpe': 1, 'tvodlulpe':1}
# _MOMENTUM_EQUILIBRIUM = {'lue': 0.99, 'odlue': 0.99, 'odlulpe': 0.99, 'tvodlulpe':0.99}
# _MOMENTUM_EQUILIBRIUM = {'lue': 0.95, 'odlue': 0.95, 'odlulpe': 0.95, 'tvodlulpe':0.95}
#_MOMENTUM_EQUILIBRIUM = {'lue': 0.8, 'odlue': 0.8, 'odlulpe': 0.8, 'tvodlulpe':0.8}

# Including historic OD matrix
# _LOSS_WEIGHTS ={'od': 1, 'tt': 1, 'flow': 1, 'eq_flow': 1}
# _MOMENTUM_EQUILIBRIUM = 0.99

# _LOSS_METRIC = mse
# _LOSS_WEIGHTS ={'od': 1, 'theta': 0, 'tt': 1e10, 'flow': 1, 'eq_flow': 1}

print(f"_LOSS_WEIGHTS: {_LOSS_WEIGHTS}, _MOMENTUM_EQUILIBRIUM: {_MOMENTUM_EQUILIBRIUM}, "
      f"epochs: { _EPOCHS}, 'LR: {_LR}")
# Out:
# _LOSS_WEIGHTS: {'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 3, 'ntrips': 0, 'prop_od': 0}, _MOMENTUM_EQUILIBRIUM: {'lue': 1, 'odlue': 1, 'odlulpe': 1, 'tvodlulpe': 1}, epochs: {'learning': 300, 'equilibrium': 100}, 'LR: 0.5

# %% [markdown]
# ## Models

# %%
run_model = dict.fromkeys(['lue', 'odlue','odlulpe', 'tvodlulpe'], True)
# run_model = dict.fromkeys(['lue', 'odlue','odlulpe', 'tvodlulpe'], False)

# run_model['lue'] = True
# run_model['odlue'] = True
# run_model['odlulpe'] = True
# run_model['tvodlulpe'] = True

# %%
train_results_dfs = {}
test_results_dfs = {}

# %% [markdown]
# ### Model 1: Estimation of utility function (LUE)

# %%
if run_model['lue']:
    print('\nLUE: Estimation of utility function')

    # To report runtime
    t0 = time.time()

    optimizer = tf.keras.optimizers.Adam(learning_rate=_LR)

    _FIXED_EFFECT = False

    utility_parameters = UtilityParameters(features_Y=['tt'],
                                           features_Z=features_Z,
                                           # initial_values ={'tt': -1, 'tt_sd': -1,
                                           #                  'median_inc': 1,
                                           #                  'incidents': -1, 'bus_stops': -1, 'intersections': -1,
                                           #                  'psc_factor': 0, 'fixed_effect': np.zeros_like(fresno_network.links)},
                                           initial_values={'psc_factor': 0,
                                                           'fixed_effect': np.zeros_like(fresno_network.links)},
                                           signs={'tt': '-', 'tt_sd': '-', 'median_inc': '+', 'incidents': '-',
                                                  'bus_stops': '-', 'intersections': '-'},
                                           trainables={'psc_factor': False, 'fixed_effect': _FIXED_EFFECT,
                                                       'tt': True, 'tt_sd': True,
                                                       # 'median_inc': False, 'incidents': False,
                                                       # 'bus_stops': False, 'intersections': False,
                                                       'median_inc': True, 'incidents': True,
                                                       'bus_stops': True, 'intersections': True
                                                       },
                                           time_varying = True
                                           )

    bpr_parameters = BPRParameters(keys=['alpha', 'beta'],
                                   initial_values={'alpha': 0.15, 'beta': 4},
                                   trainables=dict.fromkeys(['alpha', 'beta'], False),
                                   )

    od_parameters = ODParameters(key='od',
                                 initial_values=fresno_network.q.flatten(),
                                 true_values=fresno_network.q.flatten(),
                                 historic_values={10: fresno_network.q.flatten()},
                                 trainable=False)

    equilibrator = Equilibrator(
        network=fresno_network,
        utility=utility_parameters,
        max_iters=100,
        method='fw',
        iters_fw=50,
        accuracy=1e-4,
    )

    column_generator = ColumnGenerator(equilibrator=equilibrator,
                                       utility=utility_parameters,
                                       n_paths=0,
                                       ods_coverage=0.1,
                                       ods_sampling='sequential',
                                       )

    lue = PESUELOGIT(
        key='lue',
        network=fresno_network,
        dtype=tf.float64,
        equilibrator = equilibrator,
        utility=utility_parameters,
        bpr=bpr_parameters,
        od=od_parameters,
        n_periods = len(np.unique(X_train[:,:,-1].numpy().flatten()))
    )

    train_results_dfs['lue'], test_results_dfs['lue'] = lue.train(
        X_train, Y_train, X_test, Y_test,
        optimizer=optimizer,
        batch_size=_BATCH_SIZE,
        threshold_relative_gap=_RELATIVE_GAP,
        momentum_equilibrium = _MOMENTUM_EQUILIBRIUM['lue'],
        loss_weights= dict(_LOSS_WEIGHTS, od = 0),
        loss_metric=_LOSS_METRIC,
        epochs_print_interval=_EPOCHS_PRINT_INTERVAL,
        epochs=_EPOCHS)

    # Relative loss curves over epochs
    plot_predictive_performance(train_losses=train_results_dfs['lue'], val_losses=test_results_dfs['lue'],
                                xticks_spacing = _XTICKS_SPACING)

    # Compute utility parameters over time (heatmap) and value of travel time reliability (lineplot)
    theta_df = plot_utility_parameters_periods(lue, period_keys = period_keys, period_feature='hour')

    plot_rr_by_period(lue, period_keys, period_feature='hour')

    # Average reliability ratio over epochs
    plot_convergence_estimates(estimates=train_results_dfs['lue'].\
                       assign(rr = train_results_dfs['lue']['tt_sd']/train_results_dfs['lue']['tt'])[['epoch','rr']],
                           xticks_spacing = _XTICKS_SPACING)

    plt.ylabel('average reliability ratio')

    # # Distribution of fixed effects
    # sns.displot(pd.DataFrame({'fixed_effect':np.array(lue.fixed_effect)}),
    #     x="fixed_effect", multiple="stack", kind="kde", alpha = 0.8)

    #print(f"theta = {dict(zip(utility_parameters.true_values.keys(), list(lue.theta.numpy())))}")
    print(f"\ntheta:\n {theta_df.assign(rr = theta_df['tt_sd']/theta_df['tt'])}")
    print(f"alpha = {lue.alpha: 0.2f}, beta  = {lue.beta: 0.2f}")
    print(f"Avg abs diff of observed and estimated OD: {np.mean(np.abs(lue.q - fresno_network.q.flatten())): 0.2f}")
    print(f"Avg observed OD: {np.mean(np.abs(fresno_network.q.flatten())): 0.2f}")
    print(f"MAPE link flows={mape(actual=lue.observed_flows, predicted = lue.predicted_flow()):0.1f}, "
      f"MAPE travel times={mape(actual=lue.observed_traveltimes, predicted = lue.predicted_traveltime()):0.1f}")
    print(f"MSE link flows={mse(actual=lue.observed_flows, predicted = lue.predicted_flow()).numpy():0.2g}, "
  f"MSE travel times={mse(actual=lue.observed_traveltimes, predicted = lue.predicted_traveltime()).numpy():0.2g}")
    print(f'runtime: {time.time()-t0:0.1f} [s]')
# Out:
# LUE: Estimation of utility function
# hyperparameters loss function: {'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 3, 'ntrips': 0, 'prop_od': 0}
#
# Epoch: 0/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 0: train_loss=1.8e+06, val_loss=0, train_loss tt=0.11, val_loss tt=0, train_loss flow=1.8e+06, val_loss flow=0, theta = [0. 0. 0. 0. 0. 0.], avg rr = nan, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=3, relative x=2.2e-16, relative gap=0.02, train flow equilibrium loss=1.7e-25, time: 2.7
#
# Epoch: 1/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 1: train_loss=5.1e+05, val_loss=0, train_loss tt=0.1, val_loss tt=0, train_loss flow=1.7e+06, val_loss flow=0, theta = [-0.5   -0.498  0.    -0.5    0.    -0.5  ], avg rr = 1.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.19, relative gap=0.25, train flow equilibrium loss=2.8e+05, time: 5.6
#
# Epoch: 10/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 10: train_loss=2.7e+05, val_loss=0, train_loss tt=0.043, val_loss tt=0, train_loss flow=9.4e+05, val_loss flow=0, theta = [-1.774 -3.11   0.     0.     0.    -2.149], avg rr = 1.75, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.16, relative gap=0.19, train flow equilibrium loss=1.4e+05, time: 45.8
#
# Epoch: 20/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 20: train_loss=1.4e+05, val_loss=0, train_loss tt=0.023, val_loss tt=0, train_loss flow=5e+05, val_loss flow=0, theta = [-2.03  -2.428  0.     0.     0.    -2.507], avg rr = 1.20, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.11, relative gap=0.13, train flow equilibrium loss=7.6e+04, time: 50.6
#
# Epoch: 30/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 30: train_loss=9.5e+04, val_loss=0, train_loss tt=0.016, val_loss tt=0, train_loss flow=2.9e+05, val_loss flow=0, theta = [-2.097 -2.233  0.     0.     0.    -2.442], avg rr = 1.06, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.082, relative gap=0.1, train flow equilibrium loss=6.3e+04, time: 50.7
#
# Epoch: 40/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 40: train_loss=7.6e+04, val_loss=0, train_loss tt=0.014, val_loss tt=0, train_loss flow=1.9e+05, val_loss flow=0, theta = [-2.181 -1.672  0.     0.     0.    -2.242], avg rr = 0.77, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.074, relative gap=0.093, train flow equilibrium loss=6.5e+04, time: 50.3
#
# Epoch: 50/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 50: train_loss=6.7e+04, val_loss=0, train_loss tt=0.013, val_loss tt=0, train_loss flow=1.3e+05, val_loss flow=0, theta = [-2.249  0.     0.     0.     0.    -2.05 ], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.067, relative gap=0.089, train flow equilibrium loss=7e+04, time: 50.4
#
# Epoch: 60/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 60: train_loss=6.4e+04, val_loss=0, train_loss tt=0.013, val_loss tt=0, train_loss flow=9e+04, val_loss flow=0, theta = [-2.2    0.     0.     0.     0.    -1.949], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.061, relative gap=0.088, train flow equilibrium loss=7.6e+04, time: 50.8
#
# Epoch: 70/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 70: train_loss=6.3e+04, val_loss=0, train_loss tt=0.013, val_loss tt=0, train_loss flow=6.9e+04, val_loss flow=0, theta = [-2.112  0.     0.     0.     0.    -1.814], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.058, relative gap=0.087, train flow equilibrium loss=8.1e+04, time: 50.9
#
# Epoch: 80/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 80: train_loss=6.2e+04, val_loss=0, train_loss tt=0.013, val_loss tt=0, train_loss flow=5.8e+04, val_loss flow=0, theta = [-1.974  0.     0.     0.     0.    -1.641], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.057, relative gap=0.087, train flow equilibrium loss=8.5e+04, time: 50.1
#
# Epoch: 90/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 90: train_loss=6.2e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=5.2e+04, val_loss flow=0, theta = [-1.762  0.     0.     0.     0.    -1.407], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.057, relative gap=0.087, train flow equilibrium loss=8.6e+04, time: 50.3
#
# Epoch: 100/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 100: train_loss=6.2e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.9e+04, val_loss flow=0, theta = [-1.423  0.     0.     0.     0.    -1.059], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.058, relative gap=0.088, train flow equilibrium loss=8.7e+04, time: 49.8
#
# Epoch: 110/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 110: train_loss=6.1e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.8e+04, val_loss flow=0, theta = [-0.838  0.     0.     0.     0.    -0.564], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.063, relative gap=0.09, train flow equilibrium loss=8.5e+04, time: 50.6
#
# Epoch: 120/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 120: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.6e+04, val_loss flow=0, theta = [-0.456  0.     0.     0.     0.    -0.297], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.077, relative gap=0.09, train flow equilibrium loss=8.4e+04, time: 50.2
#
# Epoch: 130/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 130: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.388  0.     0.     0.     0.    -0.235], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.076, relative gap=0.087, train flow equilibrium loss=8.3e+04, time: 50.1
#
# Epoch: 140/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 140: train_loss=6.2e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.514  0.     0.     0.     0.    -0.135], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.11, relative gap=0.11, train flow equilibrium loss=8.8e+04, time: 49.8
#
# Epoch: 150/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 150: train_loss=6e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.39   0.     0.     0.     0.    -0.322], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.057, relative gap=0.093, train flow equilibrium loss=8.5e+04, time: 49.9
#
# Epoch: 160/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 160: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.4    0.     0.     0.     0.    -0.174], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.069, relative gap=0.092, train flow equilibrium loss=8.3e+04, time: 50.0
#
# Epoch: 170/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 170: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.377  0.     0.     0.     0.    -0.208], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.05, relative gap=0.083, train flow equilibrium loss=8.2e+04, time: 49.9
#
# Epoch: 180/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 180: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.363  0.     0.     0.     0.    -0.187], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.049, relative gap=0.082, train flow equilibrium loss=8.2e+04, time: 49.9
#
# Epoch: 190/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 190: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.354  0.     0.     0.     0.    -0.149], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.055, relative gap=0.084, train flow equilibrium loss=8.2e+04, time: 49.9
#
# Epoch: 200/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 200: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.353  0.     0.     0.     0.    -0.236], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.059, relative gap=0.095, train flow equilibrium loss=8.4e+04, time: 50.0
#
# Epoch: 210/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 210: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.4e+04, val_loss flow=0, theta = [-0.552  0.     0.     0.     0.    -0.215], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.054, relative gap=0.091, train flow equilibrium loss=8.4e+04, time: 49.6
#
# Epoch: 220/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 220: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.4e+04, val_loss flow=0, theta = [-0.53   0.     0.     0.     0.    -0.277], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.055, relative gap=0.088, train flow equilibrium loss=8.4e+04, time: 50.2
#
# Epoch: 230/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 230: train_loss=5.9e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.511  0.     0.     0.     0.    -0.248], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.051, relative gap=0.088, train flow equilibrium loss=8.3e+04, time: 49.8
#
# Epoch: 240/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 240: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.449  0.     0.     0.     0.    -0.199], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.048, relative gap=0.086, train flow equilibrium loss=8.2e+04, time: 53.0
#
# Epoch: 250/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 250: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.338  0.     0.     0.     0.    -0.174], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.047, relative gap=0.082, train flow equilibrium loss=8.2e+04, time: 50.7
#
# Epoch: 260/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 260: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.337  0.     0.     0.     0.    -0.161], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.047, relative gap=0.082, train flow equilibrium loss=8.2e+04, time: 50.1
#
# Epoch: 270/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 270: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.377  0.     0.     0.     0.    -0.157], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.045, relative gap=0.082, train flow equilibrium loss=8.2e+04, time: 50.3
#
# Epoch: 280/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 280: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.348  0.     0.     0.     0.    -0.146], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.044, relative gap=0.081, train flow equilibrium loss=8.1e+04, time: 50.3
#
# Epoch: 290/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 290: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.361  0.     0.     0.     0.    -0.143], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.043, relative gap=0.081, train flow equilibrium loss=8.1e+04, time: 50.6
#
# Epoch: 300/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 300: train_loss=5.8e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.357  0.     0.     0.     0.    -0.139], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=0.6, relative x=0.042, relative gap=0.08, train flow equilibrium loss=8.1e+04, time: 50.5
#
# Equilibrium stage
#
# hyperparameters loss function: {'od': 0, 'theta': 0, 'tt': 0, 'flow': 0, 'eq_flow': 1}
#
# Epoch: 0/100, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 0: train_loss=8.1e+04, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=4.5e+04, val_loss flow=0, theta = [-0.357  0.     0.     0.     0.    -0.139], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=1, relative x=0.042, relative gap=0.02, train flow equilibrium loss=8.1e+04, time: 2.5
#
# Epoch: 1/100, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 1: train_loss=7.2e+04, val_loss=0, train_loss tt=0.013, val_loss tt=0, train_loss flow=6.4e+04, val_loss flow=0, theta = [-0.357  0.     0.     0.     0.    -0.139], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=1, relative x=0.037, relative gap=0.069, train flow equilibrium loss=7.2e+04, time: 5.0
#
# Epoch: 10/100, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 10: train_loss=8.7e+03, val_loss=0, train_loss tt=0.048, val_loss tt=0, train_loss flow=1.1e+06, val_loss flow=0, theta = [-0.357  0.     0.     0.     0.    -0.139], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=1, relative x=0.012, relative gap=0.022, train flow equilibrium loss=8.7e+03, time: 45.6
#
# Epoch: 12/100, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 12: train_loss=5.2e+03, val_loss=0, train_loss tt=0.059, val_loss tt=0, train_loss flow=1.3e+06, val_loss flow=0, theta = [-0.357  0.     0.     0.     0.    -0.139], avg rr = -0.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=1, relative x=0.01, relative gap=0.018, train flow equilibrium loss=5.2e+03, time: 10.0
#
# theta:
#               tt  tt_sd  median_inc  incidents  bus_stops  intersections  hour  \
# 16-17 -0.356922    0.0         0.0        0.0        0.0      -0.139076    16
#
#         rr
# 16-17 -0.0
# alpha =  0.15, beta  =  4.00
# Avg abs diff of observed and estimated OD:  0.00
# Avg observed OD:  9.51
# MAPE link flows=96.9, MAPE travel times=28.6
# MSE link flows=1.3e+06, MSE travel times=0.059
# runtime: 1578.8 [s]
# /Users/pablo/opt/anaconda3/envs/pesuelogit/lib/python3.10/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.0, 0.0, 0.0)) for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %% [markdown]
# ### Model 2: OD + utility estimation with historic OD (ODLUE)

# %%
if run_model['odlue']:

    print('\nODLUE: OD + utility estimation with historic OD')

    # To report runtime
    t0 = time.time()

    optimizer = tf.keras.optimizers.Adam(learning_rate=_LR)

    _FIXED_EFFECT = False

    utility_parameters = UtilityParameters(features_Y=['tt'],
                                           features_Z=features_Z,
                                           initial_values={'psc_factor': 0,
                                                           'fixed_effect': np.zeros_like(fresno_network.links)},
                                           signs={'tt': '-', 'tt_sd': '-', 'median_inc': '+', 'incidents': '-',
                                                  'bus_stops': '-', 'intersections': '-'},
                                           trainables={'psc_factor': False, 'fixed_effect': _FIXED_EFFECT,
                                                       'tt': True, 'tt_sd': True,
                                                       # 'median_inc': False, 'incidents': False,
                                                       # 'bus_stops': False, 'intersections': False,
                                                       'median_inc': True, 'incidents': True,
                                                       'bus_stops': True, 'intersections': True
                                                       },
                                           time_varying = True
                                           )

    bpr_parameters = BPRParameters(keys=['alpha', 'beta'],
                                   initial_values={'alpha': 0.15, 'beta': 4},
                                   trainables=dict.fromkeys(['alpha', 'beta'], False),
                                   )

    od_parameters = ODParameters(key='od',
                                 initial_values=fresno_network.q.flatten(),
                                 historic_values={10: fresno_network.q.flatten()},
                                 # total_trips={10: 1e5},
                                 trainable=True)

    equilibrator = Equilibrator(
        network=fresno_network,
        utility=utility_parameters,
        max_iters=100,
        method='fw',
        iters_fw=50,
        accuracy=1e-4,
    )

    odlue = PESUELOGIT(
        key='odlue',
        network=fresno_network,
        dtype=tf.float64,
        equilibrator=equilibrator,
        utility=utility_parameters,
        bpr=bpr_parameters,
        od=od_parameters,
        n_periods = len(np.unique(X_train[:,:,-1].numpy().flatten()))
    )

    train_results_dfs['odlue'], test_results_dfs['odlue'] = odlue.train(
        X_train, Y_train, X_test, Y_test,
        optimizer=optimizer,
        batch_size=_BATCH_SIZE,
        loss_weights= _LOSS_WEIGHTS,
        loss_metric=_LOSS_METRIC,
        momentum_equilibrium = _MOMENTUM_EQUILIBRIUM['odlue'],
        threshold_relative_gap=_RELATIVE_GAP,
        epochs_print_interval=_EPOCHS_PRINT_INTERVAL,
        epochs=_EPOCHS)

    plot_predictive_performance(train_losses=train_results_dfs['odlue'], val_losses=test_results_dfs['odlue'],
                                xticks_spacing = _XTICKS_SPACING)

    plot_top_od_flows_periods(odlue,
                              historic_od= fresno_network.q.flatten(),
                              period_keys = period_keys,
                              period_feature='hour', top_k=20)

    # Compute utility parameters over time (heatmap) and value of travel time reliability (lineplot)
    theta_df = plot_utility_parameters_periods(odlue, period_keys = period_keys, period_feature='hour')

    plot_rr_by_period(odlue, period_keys, period_feature='hour')

    plot_convergence_estimates(estimates=train_results_dfs['odlue'].\
                       assign(rr = train_results_dfs['odlue']['tt_sd']/train_results_dfs['odlue']['tt'])[['epoch','rr']],
                           xticks_spacing = _XTICKS_SPACING)
    plt.ylabel('average reliability ratio')

    # sns.displot(pd.DataFrame({'fixed_effect':np.array(odlue.fixed_effect)}),
    #         x="fixed_effect", multiple="stack", kind="kde", alpha = 0.8)

    print(f"\ntheta:\n {theta_df.assign(rr = theta_df['tt_sd']/theta_df['tt'])}")
    print(f"alpha = {odlue.alpha: 0.2f}, beta  = {odlue.beta: 0.2f}")
    print(f"Avg abs diff of observed and estimated OD: {np.mean(np.abs(odlue.q - fresno_network.q.flatten())): 0.2f}")
    print(f"Avg observed OD: {np.mean(np.abs(fresno_network.q.flatten())): 0.2f}")
    print(f"MAPE link flows={mape(actual=odlue.observed_flows, predicted = odlue.predicted_flow()):0.1f}, "
          f"MAPE travel times={mape(actual=odlue.observed_traveltimes, predicted = odlue.predicted_traveltime()):0.1f}")
    print(f"MSE link flows={mse(actual=odlue.observed_flows, predicted = odlue.predicted_flow()).numpy():0.2g}, "
  f"MSE travel times={mse(actual=odlue.observed_traveltimes, predicted = odlue.predicted_traveltime()).numpy():0.2g}")
    print(f'runtime: {time.time()-t0:0.1f} [s]')
# Out:
# ODLUE: OD + utility estimation with historic OD
# hyperparameters loss function: {'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 3, 'ntrips': 0, 'prop_od': 0}
#
# Epoch: 0/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 0: train_loss=1.8e+06, val_loss=0, train_loss tt=0.11, val_loss tt=0, train_loss flow=1.8e+06, val_loss flow=0, theta = [0. 0. 0. 0. 0. 0.], avg rr = nan, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=3, relative x=2.2e-16, relative gap=0.02, train flow equilibrium loss=1.7e-25, time: 2.5
#
# Epoch: 1/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 1: train_loss=5.2e+05, val_loss=0, train_loss tt=0.1, val_loss tt=0, train_loss flow=1.7e+06, val_loss flow=0, theta = [-0.5   -0.498  0.    -0.5    0.    -0.5  ], avg rr = 1.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=4.9, loss ntrips=0, total trips=[6.5e+04], lambda eq=0.6, relative x=0.22, relative gap=0.27, train flow equilibrium loss=3.1e+05, time: 5.7
#
# Epoch: 10/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 10: train_loss=2.2e+05, val_loss=0, train_loss tt=0.044, val_loss tt=0, train_loss flow=9.6e+05, val_loss flow=0, theta = [-1.946 -3.424  0.    -0.507  0.    -1.899], avg rr = 1.76, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=1.5e+02, loss ntrips=0, total trips=[7.5e+04], lambda eq=0.6, relative x=0.23, relative gap=0.12, train flow equilibrium loss=4.6e+04, time: 49.2
#
# Epoch: 20/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 20: train_loss=1.1e+05, val_loss=0, train_loss tt=0.022, val_loss tt=0, train_loss flow=5.2e+05, val_loss flow=0, theta = [-2.575 -4.395  0.    -0.673  0.    -1.997], avg rr = 1.71, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.1e+02, loss ntrips=0, total trips=[7.3e+04], lambda eq=0.6, relative x=0.14, relative gap=0.073, train flow equilibrium loss=1.7e+04, time: 54.4
#
# Epoch: 30/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 30: train_loss=7.1e+04, val_loss=0, train_loss tt=0.015, val_loss tt=0, train_loss flow=3.1e+05, val_loss flow=0, theta = [-2.82  -4.811  0.    -0.699  0.    -2.035], avg rr = 1.71, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.9e+02, loss ntrips=0, total trips=[7.4e+04], lambda eq=0.6, relative x=0.1, relative gap=0.056, train flow equilibrium loss=1.4e+04, time: 54.8
#
# Epoch: 40/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 40: train_loss=4.8e+04, val_loss=0, train_loss tt=0.011, val_loss tt=0, train_loss flow=2e+05, val_loss flow=0, theta = [-2.941 -5.014  0.    -0.761  0.    -1.936], avg rr = 1.71, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=4.4e+02, loss ntrips=0, total trips=[7.4e+04], lambda eq=0.6, relative x=0.09, relative gap=0.045, train flow equilibrium loss=1.3e+04, time: 54.5
#
# Epoch: 50/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 50: train_loss=3.5e+04, val_loss=0, train_loss tt=0.0097, val_loss tt=0, train_loss flow=1.3e+05, val_loss flow=0, theta = [-3.002 -5.33   0.    -0.759  0.    -1.833], avg rr = 1.78, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=5.2e+02, loss ntrips=0, total trips=[7.7e+04], lambda eq=0.6, relative x=0.077, relative gap=0.041, train flow equilibrium loss=1.4e+04, time: 55.1
#
# Epoch: 60/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 60: train_loss=2.8e+04, val_loss=0, train_loss tt=0.0087, val_loss tt=0, train_loss flow=9.8e+04, val_loss flow=0, theta = [-3.033 -5.787  0.    -0.729  0.    -1.763], avg rr = 1.91, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=6.3e+02, loss ntrips=0, total trips=[8.0e+04], lambda eq=0.6, relative x=0.063, relative gap=0.036, train flow equilibrium loss=1.5e+04, time: 54.8
#
# Epoch: 70/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 70: train_loss=2.5e+04, val_loss=0, train_loss tt=0.008, val_loss tt=0, train_loss flow=7.8e+04, val_loss flow=0, theta = [-3.054 -6.194  0.    -0.697  0.    -1.718], avg rr = 2.03, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=7.7e+02, loss ntrips=0, total trips=[8.5e+04], lambda eq=0.6, relative x=0.056, relative gap=0.033, train flow equilibrium loss=1.5e+04, time: 53.9
#
# Epoch: 80/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 80: train_loss=2.2e+04, val_loss=0, train_loss tt=0.0075, val_loss tt=0, train_loss flow=6.5e+04, val_loss flow=0, theta = [-3.067 -6.584  0.    -0.666  0.    -1.682], avg rr = 2.15, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=9.2e+02, loss ntrips=0, total trips=[8.8e+04], lambda eq=0.6, relative x=0.053, relative gap=0.031, train flow equilibrium loss=1.5e+04, time: 54.1
#
# Epoch: 90/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 90: train_loss=2.1e+04, val_loss=0, train_loss tt=0.007, val_loss tt=0, train_loss flow=5.9e+04, val_loss flow=0, theta = [-3.073 -6.976  0.    -0.652  0.    -1.656], avg rr = 2.27, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=1.1e+03, loss ntrips=0, total trips=[9.2e+04], lambda eq=0.6, relative x=0.051, relative gap=0.03, train flow equilibrium loss=1.5e+04, time: 53.6
#
# Epoch: 100/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 100: train_loss=2.1e+04, val_loss=0, train_loss tt=0.0064, val_loss tt=0, train_loss flow=5.7e+04, val_loss flow=0, theta = [-3.065 -7.337  0.    -0.661  0.    -1.657], avg rr = 2.39, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=1.3e+03, loss ntrips=0, total trips=[9.5e+04], lambda eq=0.6, relative x=0.047, relative gap=0.028, train flow equilibrium loss=1.5e+04, time: 54.0
#
# Epoch: 110/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 110: train_loss=2e+04, val_loss=0, train_loss tt=0.006, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-3.04  -7.614  0.    -0.684  0.    -1.691], avg rr = 2.50, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=1.5e+03, loss ntrips=0, total trips=[9.8e+04], lambda eq=0.6, relative x=0.046, relative gap=0.028, train flow equilibrium loss=1.5e+04, time: 54.1
#
# Epoch: 120/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 120: train_loss=2e+04, val_loss=0, train_loss tt=0.0058, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-3.014 -7.93   0.    -0.7    0.    -1.725], avg rr = 2.63, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=1.8e+03, loss ntrips=0, total trips=[1.0e+05], lambda eq=0.6, relative x=0.046, relative gap=0.026, train flow equilibrium loss=1.5e+04, time: 54.1
#
# Epoch: 130/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 130: train_loss=2e+04, val_loss=0, train_loss tt=0.0057, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.996 -8.331  0.    -0.714  0.    -1.761], avg rr = 2.78, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=1.9e+03, loss ntrips=0, total trips=[1.0e+05], lambda eq=0.6, relative x=0.048, relative gap=0.026, train flow equilibrium loss=1.5e+04, time: 54.5
#
# Epoch: 140/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 140: train_loss=2e+04, val_loss=0, train_loss tt=0.0055, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.982 -8.717  0.    -0.71   0.    -1.803], avg rr = 2.92, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.1e+03, loss ntrips=0, total trips=[1.0e+05], lambda eq=0.6, relative x=0.048, relative gap=0.025, train flow equilibrium loss=1.5e+04, time: 54.8
#
# Epoch: 150/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 150: train_loss=2e+04, val_loss=0, train_loss tt=0.0054, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.965 -9.043  0.    -0.741  0.    -1.836], avg rr = 3.05, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.2e+03, loss ntrips=0, total trips=[1.0e+05], lambda eq=0.6, relative x=0.048, relative gap=0.026, train flow equilibrium loss=1.5e+04, time: 54.4
#
# Epoch: 160/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 160: train_loss=2e+04, val_loss=0, train_loss tt=0.0053, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.956 -9.32   0.    -0.731  0.    -1.9  ], avg rr = 3.15, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.4e+03, loss ntrips=0, total trips=[1.1e+05], lambda eq=0.6, relative x=0.046, relative gap=0.024, train flow equilibrium loss=1.5e+04, time: 54.0
#
# Epoch: 170/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 170: train_loss=2e+04, val_loss=0, train_loss tt=0.0052, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.942 -9.482  0.    -0.749  0.    -1.962], avg rr = 3.22, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e+03, loss ntrips=0, total trips=[1.1e+05], lambda eq=0.6, relative x=0.045, relative gap=0.023, train flow equilibrium loss=1.5e+04, time: 54.0
#
# Epoch: 180/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 180: train_loss=2e+04, val_loss=0, train_loss tt=0.0051, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.929 -9.581  0.    -0.77   0.    -2.026], avg rr = 3.27, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.7e+03, loss ntrips=0, total trips=[1.1e+05], lambda eq=0.6, relative x=0.045, relative gap=0.023, train flow equilibrium loss=1.5e+04, time: 54.1
#
# Epoch: 190/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 190: train_loss=2e+04, val_loss=0, train_loss tt=0.005, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.92  -9.625  0.    -0.798  0.    -2.092], avg rr = 3.30, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.8e+03, loss ntrips=0, total trips=[1.1e+05], lambda eq=0.6, relative x=0.047, relative gap=0.023, train flow equilibrium loss=1.5e+04, time: 54.1
#
# Epoch: 200/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 200: train_loss=2e+04, val_loss=0, train_loss tt=0.0049, val_loss tt=0, train_loss flow=5.5e+04, val_loss flow=0, theta = [-2.921 -9.603  0.    -0.821  0.    -2.16 ], avg rr = 3.29, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3e+03, loss ntrips=0, total trips=[1.1e+05], lambda eq=0.6, relative x=0.048, relative gap=0.023, train flow equilibrium loss=1.5e+04, time: 54.3
#
# Epoch: 210/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 210: train_loss=2e+04, val_loss=0, train_loss tt=0.0048, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-2.932 -9.552  0.    -0.838  0.    -2.223], avg rr = 3.26, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.1e+03, loss ntrips=0, total trips=[1.1e+05], lambda eq=0.6, relative x=0.048, relative gap=0.022, train flow equilibrium loss=1.5e+04, time: 53.9
#
# Epoch: 220/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 220: train_loss=2e+04, val_loss=0, train_loss tt=0.0047, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-2.948 -9.537  0.    -0.853  0.    -2.266], avg rr = 3.23, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.2e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.047, relative gap=0.022, train flow equilibrium loss=1.5e+04, time: 54.4
#
# Epoch: 230/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 230: train_loss=2e+04, val_loss=0, train_loss tt=0.0047, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-2.968 -9.535  0.    -0.866  0.    -2.295], avg rr = 3.21, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.3e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.047, relative gap=0.021, train flow equilibrium loss=1.5e+04, time: 54.3
#
# Epoch: 240/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 240: train_loss=2e+04, val_loss=0, train_loss tt=0.0047, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-2.989 -9.522  0.    -0.875  0.    -2.323], avg rr = 3.19, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.4e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.047, relative gap=0.021, train flow equilibrium loss=1.5e+04, time: 54.3
#
# Epoch: 250/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 250: train_loss=2e+04, val_loss=0, train_loss tt=0.0046, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.01  -9.503  0.    -0.885  0.    -2.349], avg rr = 3.16, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.5e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.048, relative gap=0.021, train flow equilibrium loss=1.5e+04, time: 54.0
#
# Epoch: 260/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 260: train_loss=2e+04, val_loss=0, train_loss tt=0.0046, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.027 -9.499  0.    -0.902  0.    -2.374], avg rr = 3.14, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.6e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.05, relative gap=0.022, train flow equilibrium loss=1.5e+04, time: 53.7
#
# Epoch: 270/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 270: train_loss=2e+04, val_loss=0, train_loss tt=0.0046, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.043 -9.527  0.    -0.911  0.    -2.405], avg rr = 3.13, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.7e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.049, relative gap=0.021, train flow equilibrium loss=1.5e+04, time: 54.5
#
# Epoch: 280/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 280: train_loss=2e+04, val_loss=0, train_loss tt=0.0046, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.055 -9.588  0.    -0.926  0.    -2.435], avg rr = 3.14, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.8e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.05, relative gap=0.02, train flow equilibrium loss=1.5e+04, time: 54.3
#
# Epoch: 290/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 290: train_loss=2e+04, val_loss=0, train_loss tt=0.0046, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.068 -9.684  0.    -0.928  0.    -2.468], avg rr = 3.16, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=3.9e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.052, relative gap=0.022, train flow equilibrium loss=1.5e+04, time: 54.1
#
# Epoch: 300/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 300: train_loss=2e+04, val_loss=0, train_loss tt=0.0045, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.079 -9.798  0.    -0.949  0.    -2.491], avg rr = 3.18, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=4.1e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=0.6, relative x=0.051, relative gap=0.021, train flow equilibrium loss=1.5e+04, time: 54.0
#
# Equilibrium stage
#
# hyperparameters loss function: {'od': 0, 'theta': 0, 'tt': 0, 'flow': 0, 'eq_flow': 1}
#
# Epoch: 0/100, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 0: train_loss=1.5e+04, val_loss=0, train_loss tt=0.0045, val_loss tt=0, train_loss flow=5.6e+04, val_loss flow=0, theta = [-3.079 -9.798  0.    -0.949  0.    -2.491], avg rr = 3.18, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=4.1e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=1, relative x=0.051, relative gap=0.02, train flow equilibrium loss=1.5e+04, time: 2.4
#
# Epoch: 1/100, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 1: train_loss=1.2e+04, val_loss=0, train_loss tt=0.0049, val_loss tt=0, train_loss flow=7.4e+04, val_loss flow=0, theta = [-3.079 -9.798  0.    -0.949  0.    -2.491], avg rr = 3.18, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=4.1e+03, loss ntrips=0, total trips=[1.2e+05], lambda eq=1, relative x=0.048, relative gap=0.018, train flow equilibrium loss=1.2e+04, time: 4.8
# /Users/pablo/opt/anaconda3/envs/pesuelogit/lib/python3.10/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.0, 0.0, 0.0)) for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# theta:
#               tt     tt_sd  median_inc  incidents  bus_stops  intersections  \
# 16-17 -3.078616 -9.797547         0.0   -0.94944        0.0      -2.491204
#
#        hour        rr
# 16-17    16  3.182452
# alpha =  0.15, beta  =  4.00
# Avg abs diff of observed and estimated OD:  17.83
# Avg observed OD:  9.51
# MAPE link flows=30.8, MAPE travel times=12.1
# MSE link flows=7.4e+04, MSE travel times=0.0049
# runtime: 1639.0 [s]

# %% [markdown]
# ### Model 3: ODLUE + link specific performance parameters (ODLULPE)

# %%
if run_model['odlulpe']:

    print('\nODLULPE: ODLUE + link performance parameters with historic OD matrix (link specifics alphas and betas)')

    # To report runtime
    t0 = time.time()

    # _MOMENTUM_EQUILIBRIUM = 0.99
    _FIXED_EFFECT = False

    optimizer = tf.keras.optimizers.Adam(learning_rate=_LR)

    bpr_parameters = BPRParameters(keys=['alpha', 'beta'],
                                   initial_values={'alpha': 0.15*np.ones_like(fresno_network.links,dtype = np.float32),
                                                   'beta': 4*np.ones_like(fresno_network.links,dtype = np.float32),
                                                   # 'beta': 4
                                                   },
                                   trainables={'alpha': True, 'beta': True},
                                   # trainables={'alpha': True, 'beta': False},
                                   )

    od_parameters = ODParameters(key='od',
                                 initial_values=fresno_network.q.flatten(),
                                 historic_values={10: fresno_network.q.flatten()},
                                 # total_trips={10: 1e5},
                                 trainable=True
                                 )

    utility_parameters = UtilityParameters(features_Y=['tt'],
                                           features_Z=features_Z,
                                           initial_values={'psc_factor': 0,
                                                           'fixed_effect': np.zeros_like(fresno_network.links)},
                                           signs={'tt': '-', 'tt_sd': '-',
                                                  'median_inc': '+', 'incidents': '-',
                                                  'bus_stops': '-', 'intersections': '-'
                                                  },
                                           trainables={'psc_factor': False, 'fixed_effect': _FIXED_EFFECT,
                                                       'tt': True, 'tt_sd': True,
                                                       'median_inc': True, 'incidents': True,
                                                       'bus_stops': True, 'intersections': True
                                                       },
                                           time_varying = True
                                           )

    equilibrator = Equilibrator(
        network=fresno_network,
        # paths_generator=paths_generator,
        utility=utility_parameters,
        max_iters=100,
        method='fw',
        iters_fw=50,
        accuracy=1e-4,
    )

    odlulpe = PESUELOGIT(
        key='odlulpe',
        network=fresno_network,
        dtype=tf.float64,
        equilibrator=equilibrator,
        utility=utility_parameters,
        bpr=bpr_parameters,
        od=od_parameters,
        n_periods = len(np.unique(X_train[:,:,-1].numpy().flatten()))
    )

    train_results_dfs['odlulpe'], test_results_dfs['odlulpe'] = odlulpe.train(
        X_train, Y_train, X_test, Y_test,
        optimizer=optimizer,
        # generalization_error={'train': False, 'validation': True},
        batch_size=_BATCH_SIZE,
        # loss_weights={'od': 1, 'theta': 0, 'tt': 1, 'flow': 1, 'eq_flow': 1},
        loss_weights=_LOSS_WEIGHTS,
        momentum_equilibrium = _MOMENTUM_EQUILIBRIUM['odlulpe'],
        threshold_relative_gap=_RELATIVE_GAP,
        epochs_print_interval=_EPOCHS_PRINT_INTERVAL,
        loss_metric=_LOSS_METRIC,
        epochs=_EPOCHS)



    plot_predictive_performance(train_losses=train_results_dfs['odlulpe'], val_losses=test_results_dfs['odlulpe'],
                                xticks_spacing = _XTICKS_SPACING)

    plot_convergence_estimates(estimates=train_results_dfs['odlulpe'][['epoch','alpha','beta']],
                                xticks_spacing = _XTICKS_SPACING)
    
    plt.ylabel("average value")

    sns.displot(pd.melt(pd.DataFrame({'alpha':odlulpe.alpha, 'beta': odlulpe.beta}), var_name = 'parameters'),
                x="value", hue="parameters", alpha = 0.8)

    top_q, total_trips_by_hour = plot_top_od_flows_periods(odlulpe,
                                                           historic_od= fresno_network.q.flatten(),
                                                           period_keys = period_keys,
                                                           period_feature='hour', top_k=20)

    # Compute utility parameters over time (heatmap) and value of travel time reliability (lineplot)
    theta_df = plot_utility_parameters_periods(odlulpe, period_keys = period_keys, period_feature='hour')

    plot_rr_by_period(odlulpe, period_keys, period_feature='hour')


    plot_convergence_estimates(estimates=train_results_dfs['odlulpe'].\
                   assign(rr = train_results_dfs['odlulpe']['tt_sd']/train_results_dfs['odlulpe']['tt'])[['epoch','rr']],
                       xticks_spacing = _XTICKS_SPACING)

    plt.ylabel('average reliability ratio')

    # sns.displot(pd.DataFrame({'fixed_effect':np.array(odlulpe.fixed_effect)}),
    #             x="fixed_effect", multiple="stack", kind="kde", alpha = 0.8)

    #print(f"theta = {dict(zip(utility_parameters.true_values.keys(), list(odlulpe.theta.numpy())))}")
    print(f"\ntheta:\n {theta_df.assign(rr = theta_df['tt_sd']/theta_df['tt'])}")
    print(f"alpha = {np.mean(odlulpe.alpha): 0.2f}, beta  = {np.mean(odlulpe.beta): 0.2f}")
    print(f"Avg abs diff of observed and estimated OD: {np.mean(np.abs(odlulpe.q - fresno_network.q.flatten())): 0.2f}")
    print(f"Avg observed OD: {np.mean(np.abs(fresno_network.q.flatten())): 0.2f}")
    print(f"MAPE link flows={mape(actual=odlulpe.observed_flows, predicted = odlulpe.predicted_flow()):0.1f}, "
          f"MAPE travel times={mape(actual=odlulpe.observed_traveltimes, predicted = odlulpe.predicted_traveltime()):0.1f}")
    print(f"MSE link flows={mse(actual=odlulpe.observed_flows, predicted = odlulpe.predicted_flow()).numpy():0.2g}, "
      f"MSE travel times={mse(actual=odlulpe.observed_traveltimes, predicted = odlulpe.predicted_traveltime()).numpy():0.2g}")
    print(f'runtime: {time.time()-t0:0.1f} [s]')
# Out:
# ODLULPE: ODLUE + link performance parameters with historic OD matrix (link specifics alphas and betas)
# hyperparameters loss function: {'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 3.0, 'ntrips': 0, 'prop_od': 0}
#
# Epoch: 0/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 0: train_loss=1.8e+06, val_loss=0, train_loss tt=0.11, val_loss tt=0, train_loss flow=1.8e+06, val_loss flow=0, theta = [0. 0. 0. 0. 0. 0.], avg rr = nan, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04], lambda eq=3, relative x=2.2e-16, relative gap=0.02, train flow equilibrium loss=1.7e-25, time: 2.5
#
# Epoch: 1/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 1: train_loss=5.2e+05, val_loss=0, train_loss tt=0.012, val_loss tt=0, train_loss flow=1.7e+06, val_loss flow=0, theta = [-0.5   -0.498  0.    -0.5    0.    -0.5  ], avg rr = 1.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=3.8, loss prop od=4.9, loss ntrips=0, total trips=[6.5e+04], lambda eq=0.6, relative x=0.22, relative gap=0.27, train flow equilibrium loss=3e+05, time: 5.4
#
# Epoch: 10/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 10: train_loss=2.2e+05, val_loss=0, train_loss tt=0.004, val_loss tt=0, train_loss flow=1e+06, val_loss flow=0, theta = [-1.97  -2.561  0.    -0.648  0.    -1.635], avg rr = 1.30, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.23, avg beta=2.8, loss prop od=1.4e+02, loss ntrips=0, total trips=[7.5e+04], lambda eq=0.6, relative x=0.22, relative gap=0.11, train flow equilibrium loss=3.8e+04, time: 48.5
#
# Epoch: 20/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 20: train_loss=1.3e+05, val_loss=0, train_loss tt=0.0024, val_loss tt=0, train_loss flow=5.8e+05, val_loss flow=0, theta = [-2.447 -3.072  0.    -0.766  0.    -1.665], avg rr = 1.26, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.23, avg beta=2.6, loss prop od=3e+02, loss ntrips=0, total trips=[7.5e+04], lambda eq=0.6, relative x=0.12, relative gap=0.066, train flow equilibrium loss=1.5e+04, time: 53.9
#
# Epoch: 30/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 30: train_loss=8e+04, val_loss=0, train_loss tt=0.0021, val_loss tt=0, train_loss flow=3.6e+05, val_loss flow=0, theta = [-2.61  -3.115  0.    -0.746  0.    -1.8  ], avg rr = 1.19, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.23, avg beta=2.5, loss prop od=3.8e+02, loss ntrips=0, total trips=[7.3e+04], lambda eq=0.6, relative x=0.094, relative gap=0.049, train flow equilibrium loss=1.2e+04, time: 54.6
#
# Epoch: 40/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 40: train_loss=5.5e+04, val_loss=0, train_loss tt=0.0018, val_loss tt=0, train_loss flow=2.4e+05, val_loss flow=0, theta = [-2.683 -3.005  0.    -0.86   0.    -1.822], avg rr = 1.12, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.24, avg beta=2.4, loss prop od=4.2e+02, loss ntrips=0, total trips=[7.3e+04], lambda eq=0.6, relative x=0.081, relative gap=0.038, train flow equilibrium loss=1e+04, time: 54.4
#
# Epoch: 50/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 50: train_loss=3.9e+04, val_loss=0, train_loss tt=0.0017, val_loss tt=0, train_loss flow=1.6e+05, val_loss flow=0, theta = [-2.701 -2.729  0.    -0.884  0.    -1.87 ], avg rr = 1.01, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.24, avg beta=2.4, loss prop od=4.8e+02, loss ntrips=0, total trips=[7.3e+04], lambda eq=0.6, relative x=0.063, relative gap=0.032, train flow equilibrium loss=1.1e+04, time: 53.8
#
# Epoch: 60/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 60: train_loss=2.9e+04, val_loss=0, train_loss tt=0.0016, val_loss tt=0, train_loss flow=1.1e+05, val_loss flow=0, theta = [-2.712 -2.704  0.    -0.868  0.    -1.923], avg rr = 1.00, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.25, avg beta=2.4, loss prop od=5.5e+02, loss ntrips=0, total trips=[7.3e+04], lambda eq=0.6, relative x=0.05, relative gap=0.029, train flow equilibrium loss=1.1e+04, time: 54.5
#
# Epoch: 70/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 70: train_loss=2.3e+04, val_loss=0, train_loss tt=0.0015, val_loss tt=0, train_loss flow=7.9e+04, val_loss flow=0, theta = [-2.724 -2.78   0.    -0.913  0.    -1.906], avg rr = 1.02, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.26, avg beta=2.3, loss prop od=6.4e+02, loss ntrips=0, total trips=[7.4e+04], lambda eq=0.6, relative x=0.047, relative gap=0.031, train flow equilibrium loss=1.3e+04, time: 54.1
#
# Epoch: 80/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 80: train_loss=1.9e+04, val_loss=0, train_loss tt=0.0015, val_loss tt=0, train_loss flow=5.8e+04, val_loss flow=0, theta = [-2.757 -3.13   0.    -0.874  0.    -1.862], avg rr = 1.14, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.26, avg beta=2.3, loss prop od=7.5e+02, loss ntrips=0, total trips=[7.5e+04], lambda eq=0.6, relative x=0.046, relative gap=0.028, train flow equilibrium loss=1.3e+04, time: 55.4
#
# Epoch: 90/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 90: train_loss=1.8e+04, val_loss=0, train_loss tt=0.0014, val_loss tt=0, train_loss flow=4.8e+04, val_loss flow=0, theta = [-2.78  -3.393  0.    -0.853  0.    -1.855], avg rr = 1.22, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.27, avg beta=2.3, loss prop od=8.6e+02, loss ntrips=0, total trips=[7.5e+04], lambda eq=0.6, relative x=0.043, relative gap=0.027, train flow equilibrium loss=1.3e+04, time: 55.0
#
# Epoch: 100/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 100: train_loss=1.7e+04, val_loss=0, train_loss tt=0.0013, val_loss tt=0, train_loss flow=4.4e+04, val_loss flow=0, theta = [-2.805 -3.578  0.    -0.799  0.    -1.866], avg rr = 1.28, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.27, avg beta=2.3, loss prop od=9.7e+02, loss ntrips=0, total trips=[7.6e+04], lambda eq=0.6, relative x=0.04, relative gap=0.023, train flow equilibrium loss=1.3e+04, time: 55.1
#
# Epoch: 110/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 110: train_loss=1.6e+04, val_loss=0, train_loss tt=0.0012, val_loss tt=0, train_loss flow=4.3e+04, val_loss flow=0, theta = [-2.824 -3.671  0.    -0.757  0.    -1.891], avg rr = 1.30, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.28, avg beta=2.3, loss prop od=1.1e+03, loss ntrips=0, total trips=[7.7e+04], lambda eq=0.6, relative x=0.038, relative gap=0.022, train flow equilibrium loss=1.3e+04, time: 54.3
#
# Epoch: 120/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 120: train_loss=1.6e+04, val_loss=0, train_loss tt=0.0012, val_loss tt=0, train_loss flow=4.3e+04, val_loss flow=0, theta = [-2.844 -3.748  0.    -0.745  0.    -1.901], avg rr = 1.32, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.28, avg beta=2.3, loss prop od=1.1e+03, loss ntrips=0, total trips=[7.7e+04], lambda eq=0.6, relative x=0.037, relative gap=0.02, train flow equilibrium loss=1.2e+04, time: 54.5
#
# Epoch: 127/300, n_periods: 1,  n_timepoints: 15, coverage t, x: [0.87 0.06]
# 127: train_loss=1.6e+04, val_loss=0, train_loss tt=0.0012, val_loss tt=0, train_loss flow=4.3e+04, val_loss flow=0, theta = [-2.859 -3.798  0.    -0.753  0.    -1.898], avg rr = 1.33, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.28, avg beta=2.3, loss prop od=1.2e+03, loss ntrips=0, total trips=[7.7e+04], lambda eq=0.6, relative x=0.037, relative gap=0.02, train flow equilibrium loss=1.2e+04, time: 37.7
#
# theta:
#               tt     tt_sd  median_inc  incidents  bus_stops  intersections  \
# 16-17 -2.858565 -3.798438         0.0   -0.75326        0.0      -1.897643
#
#        hour        rr
# 16-17    16  1.328792
# alpha =  0.28, beta  =  2.27
# Avg abs diff of observed and estimated OD:  9.93
# Avg observed OD:  9.51
# MAPE link flows=26.1, MAPE travel times=5.2
# MSE link flows=4.3e+04, MSE travel times=0.0012
# runtime: 695.3 [s]
# /Users/pablo/opt/anaconda3/envs/pesuelogit/lib/python3.10/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.0, 0.0, 0.0)) for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %% [markdown]
# ### Model 4: ODLULPE with Time Varying OD and Utility Function (TVODLULPE)

# %%
if run_model['tvodlulpe']:
    print('\ntvodlulpe: Time specific utility and OD, link performance parameters')

    # To report runtime
    t0 = time.time()

    # Only in this model, we can add fixed effect and have identifiable utility function coefficients
    _FIXED_EFFECT = True

    optimizer = tf.keras.optimizers.Adam(learning_rate=_LR)

    utility_parameters = UtilityParameters(features_Y=['tt'],
                                           features_Z=features_Z,
                                           # initial_values ={'tt': -1, 'tt_sd': -1,
                                           #                  'median_inc': 1,
                                           #                  'incidents': -1, 'bus_stops': -1, 'intersections': -1,
                                           #                  'psc_factor': 0, 'fixed_effect': np.zeros_like(fresno_network.links)},
                                           initial_values={'tt': 0, 'tt_sd': 0, 's': 0, 'psc_factor': 0,
                                                           'fixed_effect': np.zeros_like(fresno_network.links)},
                                           signs={'tt': '-',
                                                  'tt_sd': '-',
                                                  'median_inc': '+', 'incidents': '-',
                                                  'bus_stops': '-', 'intersections': '-'
                                                  },
                                           trainables={'psc_factor': False, 'fixed_effect': _FIXED_EFFECT,
                                                       'tt': True, 'tt_sd': True,
                                                       # 'median_inc': False, 'incidents': False,
                                                       # 'bus_stops': False, 'intersections': False,
                                                       'median_inc': True, 'incidents': True,
                                                       'bus_stops': True, 'intersections': True
                                                       },
                                           time_varying=True,
                                           )

    bpr_parameters = BPRParameters(keys=['alpha', 'beta'],
                                   initial_values={'alpha': 0.15*np.ones_like(fresno_network.links,dtype = np.float32),
                                                   'beta': 4*np.ones_like(fresno_network.links,dtype = np.float32),
                                                   # 'beta': 4
                                                   },
                                   trainables={'alpha': True, 'beta': True},
                                   )

    od_parameters = ODParameters(key='od',
                                 initial_values=fresno_network.q.flatten(),
                                 true_values=fresno_network.q.flatten(),
                                 historic_values={10: fresno_network.q.flatten()},
                                 # total_trips={0: 1e5, 1:1e5, 2: 1e5, 9: 1e5, 10: 1e5, 11: 1e5},
                                 # total_trips={i:1e5 for i in [0,1,2,9,10,11]},
                                 time_varying=True,
                                 trainable=True)

    tvodlulpe = PESUELOGIT(
        key='tvodlulpe',
        network=fresno_network,
        dtype=tf.float64,
        utility=utility_parameters,
        bpr=bpr_parameters,
        od=od_parameters,
        n_periods = len(np.unique(XT_train[:,:,-1].numpy().flatten()))
    )

    train_results_dfs['tvodlulpe'], test_results_dfs['tvodlulpe'] = tvodlulpe.train(
        XT_train, YT_train, XT_test, YT_test,
        optimizer=optimizer,
        batch_size=_BATCH_SIZE,
        loss_weights= _LOSS_WEIGHTS,
        loss_metric=_LOSS_METRIC,
        momentum_equilibrium=_MOMENTUM_EQUILIBRIUM['tvodlulpe'],
        threshold_relative_gap=_RELATIVE_GAP,
        epochs_print_interval=_EPOCHS_PRINT_INTERVAL,
        epochs=_EPOCHS)

    plot_predictive_performance(train_losses=train_results_dfs['tvodlulpe'], val_losses=test_results_dfs['tvodlulpe'],
                               xticks_spacing=_XTICKS_SPACING)

    plot_convergence_estimates(estimates=train_results_dfs['tvodlulpe'][['epoch', 'alpha', 'beta']],
                               xticks_spacing=_XTICKS_SPACING)

    plt.ylabel("average value")

    g = sns.displot(pd.melt(pd.DataFrame({'alpha':tvodlulpe.alpha, 'beta': tvodlulpe.beta}), var_name = 'parameters'),
                x="value", hue="parameters", alpha = 0.8)

    top_q, total_trips_by_hour = plot_top_od_flows_periods(tvodlulpe,
                                                           period_keys = period_keys,
                                                           historic_od= fresno_network.q.flatten(),
                                                           period_feature='hour', top_k=20)

    # Compute utility parameters over time (heatmap) and value of travel time reliability (lineplot)
    theta_df = plot_utility_parameters_periods(tvodlulpe, period_keys = period_keys, period_feature='hour')
    theta_df

    plot_rr_by_period(tvodlulpe, period_keys, period_feature='hour')

    plot_convergence_estimates(estimates=train_results_dfs['tvodlulpe'].\
               assign(rr = train_results_dfs['tvodlulpe']['tt_sd']/train_results_dfs['tvodlulpe']['tt'])[['epoch','rr']],
                   xticks_spacing = _XTICKS_SPACING)
    plt.ylabel('average reliability ratio')

    sns.displot(pd.DataFrame({'fixed_effect':np.array(tvodlulpe.fixed_effect)}),
            x="fixed_effect", multiple="stack", kind="kde", alpha = 0.8)

    # print(f"theta = {dict(zip(utility_parameters.true_values.keys(), list(tvodlulpe.theta.numpy())))}")
    print(f"\ntheta:\n {theta_df.assign(rr = theta_df['tt_sd']/theta_df['tt'])}")
    print(f"alpha = {np.mean(tvodlulpe.alpha): 0.2f}, beta  = {np.mean(tvodlulpe.beta): 0.2f}")
    print(f"Avg abs diff of observed and estimated OD: {np.mean(np.abs(tvodlulpe.q - fresno_network.q.flatten())): 0.2f}")
    print(f"Avg observed OD: {np.mean(np.abs(fresno_network.q.flatten())): 0.2f}")
    print(f"MAPE link flows={mape(actual=tvodlulpe.observed_flows, predicted = tvodlulpe.flows()):0.1f},"
      f"MAPE travel times={mape(actual=tvodlulpe.observed_traveltimes, predicted = tvodlulpe.traveltimes()):0.1f}")
    print(f"MSE link flows={mse(actual=tvodlulpe.observed_flows, predicted=tvodlulpe.predicted_flow()).numpy():0.2g}, "
          f"MSE travel times={mse(actual=tvodlulpe.observed_traveltimes, predicted=tvodlulpe.predicted_traveltime()).numpy():0.2g},"
           f"MSE equilibrium flows={mse(actual=tvodlulpe.flows(), predicted=tvodlulpe.compute_link_flows(XT_train)).numpy():0.2g}")
    print(f'runtime: {time.time()-t0:0.1f} [s]')
# Out:
# tvodlulpe: Time specific utility and OD, link performance parameters
# hyperparameters loss function: {'od': 0, 'tt': 1, 'flow': 1, 'eq_flow': 3.0, 'ntrips': 0, 'prop_od': 0}
#
# Epoch: 0/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 0: train_loss=2.1e+06, val_loss=0, train_loss tt=0.11, val_loss tt=0, train_loss flow=2.1e+06, val_loss flow=0, theta = [0. 0. 0. 0. 0. 0.], avg rr = nan, psc_factor = 0.0, avg theta fixed effect = 0, avg alpha=0.15, avg beta=4, loss prop od=2.5e-29, loss ntrips=0, total trips=[6.6e+04 6.6e+04 6.6e+04 6.6e+04 6.6e+04 6.6e+04], lambda eq=3, relative x=2.2e-16, relative gap=0.02, train flow equilibrium loss=1.7e-25, time: 6.4
#
# Epoch: 1/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 1: train_loss=5.9e+05, val_loss=0, train_loss tt=0.0092, val_loss tt=0, train_loss flow=2e+06, val_loss flow=0, theta = [-0.5   -0.488  0.    -0.499  0.    -0.5  ], avg rr = 0.98, psc_factor = 0.0, avg theta fixed effect = 4.9e-05, avg alpha=0.15, avg beta=3.8, loss prop od=2.2, loss ntrips=0, total trips=[6.5e+04 6.5e+04 6.5e+04 6.5e+04 6.5e+04 6.5e+04], lambda eq=0.6, relative x=0.22, relative gap=0.28, train flow equilibrium loss=3.3e+05, time: 13.1
#
# Epoch: 10/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 10: train_loss=2.8e+05, val_loss=0, train_loss tt=0.0043, val_loss tt=0, train_loss flow=1.2e+06, val_loss flow=0, theta = [-2.162 -2.658  0.    -3.017  0.    -2.703], avg rr = 1.23, psc_factor = 0.0, avg theta fixed effect = -0.077, avg alpha=0.2, avg beta=3.1, loss prop od=1.1e+02, loss ntrips=0, total trips=[7.2e+04 7.2e+04 7.2e+04 7.3e+04 7.3e+04 7.3e+04], lambda eq=0.6, relative x=0.22, relative gap=0.14, train flow equilibrium loss=5.8e+04, time: 115.0
#
# Epoch: 20/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 20: train_loss=1.5e+05, val_loss=0, train_loss tt=0.0031, val_loss tt=0, train_loss flow=7.1e+05, val_loss flow=0, theta = [-2.711 -3.22   0.    -4.056  0.    -3.384], avg rr = 1.19, psc_factor = 0.0, avg theta fixed effect = -0.1, avg alpha=0.21, avg beta=3, loss prop od=3.2e+02, loss ntrips=0, total trips=[7.0e+04 7.0e+04 7.0e+04 7.3e+04 7.3e+04 7.3e+04], lambda eq=0.6, relative x=0.18, relative gap=0.081, train flow equilibrium loss=1.9e+04, time: 128.3
#
# Epoch: 30/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 30: train_loss=9.4e+04, val_loss=0, train_loss tt=0.0024, val_loss tt=0, train_loss flow=4.3e+05, val_loss flow=0, theta = [-2.916 -3.379  0.    -4.403  0.    -3.653], avg rr = 1.16, psc_factor = 0.0, avg theta fixed effect = -0.11, avg alpha=0.24, avg beta=3.1, loss prop od=4.3e+02, loss ntrips=0, total trips=[6.8e+04 6.8e+04 6.7e+04 7.3e+04 7.3e+04 7.3e+04], lambda eq=0.6, relative x=0.14, relative gap=0.06, train flow equilibrium loss=1.4e+04, time: 129.0
#
# Epoch: 40/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 40: train_loss=6.2e+04, val_loss=0, train_loss tt=0.0021, val_loss tt=0, train_loss flow=2.8e+05, val_loss flow=0, theta = [-3.001 -3.385  0.    -4.551  0.    -3.767], avg rr = 1.13, psc_factor = 0.0, avg theta fixed effect = -0.12, avg alpha=0.31, avg beta=3.3, loss prop od=4.5e+02, loss ntrips=0, total trips=[6.5e+04 6.6e+04 6.5e+04 7.2e+04 7.2e+04 7.2e+04], lambda eq=0.6, relative x=0.11, relative gap=0.045, train flow equilibrium loss=1.1e+04, time: 128.2
#
# Epoch: 50/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 50: train_loss=4.4e+04, val_loss=0, train_loss tt=0.0018, val_loss tt=0, train_loss flow=1.9e+05, val_loss flow=0, theta = [-3.033 -3.36   0.    -4.625  0.    -3.818], avg rr = 1.11, psc_factor = 0.0, avg theta fixed effect = -0.12, avg alpha=0.44, avg beta=3.5, loss prop od=5.1e+02, loss ntrips=0, total trips=[6.4e+04 6.5e+04 6.4e+04 7.3e+04 7.3e+04 7.3e+04], lambda eq=0.6, relative x=0.095, relative gap=0.037, train flow equilibrium loss=9.3e+03, time: 128.5
#
# Epoch: 60/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 60: train_loss=3.2e+04, val_loss=0, train_loss tt=0.0017, val_loss tt=0, train_loss flow=1.3e+05, val_loss flow=0, theta = [-3.045 -3.344  0.    -4.634  0.    -3.845], avg rr = 1.10, psc_factor = 0.0, avg theta fixed effect = -0.12, avg alpha=0.57, avg beta=3.7, loss prop od=5.6e+02, loss ntrips=0, total trips=[6.3e+04 6.4e+04 6.3e+04 7.3e+04 7.4e+04 7.4e+04], lambda eq=0.6, relative x=0.084, relative gap=0.033, train flow equilibrium loss=9.1e+03, time: 128.5
#
# Epoch: 70/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 70: train_loss=2.4e+04, val_loss=0, train_loss tt=0.0016, val_loss tt=0, train_loss flow=9.1e+04, val_loss flow=0, theta = [-3.051 -3.327  0.    -4.634  0.    -3.86 ], avg rr = 1.09, psc_factor = 0.0, avg theta fixed effect = -0.12, avg alpha=0.68, avg beta=3.8, loss prop od=6.2e+02, loss ntrips=0, total trips=[6.3e+04 6.4e+04 6.2e+04 7.4e+04 7.4e+04 7.4e+04], lambda eq=0.6, relative x=0.072, relative gap=0.03, train flow equilibrium loss=9.6e+03, time: 129.0
#
# Epoch: 80/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 80: train_loss=1.9e+04, val_loss=0, train_loss tt=0.0015, val_loss tt=0, train_loss flow=6.4e+04, val_loss flow=0, theta = [-3.054 -3.3    0.    -4.628  0.    -3.866], avg rr = 1.08, psc_factor = 0.0, avg theta fixed effect = -0.12, avg alpha=0.75, avg beta=3.9, loss prop od=6.8e+02, loss ntrips=0, total trips=[6.3e+04 6.4e+04 6.2e+04 7.4e+04 7.5e+04 7.4e+04], lambda eq=0.6, relative x=0.067, relative gap=0.029, train flow equilibrium loss=1e+04, time: 128.2
#
# Epoch: 90/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 90: train_loss=1.6e+04, val_loss=0, train_loss tt=0.0015, val_loss tt=0, train_loss flow=4.9e+04, val_loss flow=0, theta = [-3.055 -3.28   0.    -4.618  0.    -3.872], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.79, avg beta=4, loss prop od=7.5e+02, loss ntrips=0, total trips=[6.3e+04 6.4e+04 6.2e+04 7.5e+04 7.5e+04 7.5e+04], lambda eq=0.6, relative x=0.06, relative gap=0.027, train flow equilibrium loss=1.1e+04, time: 128.6
#
# Epoch: 100/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 100: train_loss=1.5e+04, val_loss=0, train_loss tt=0.0014, val_loss tt=0, train_loss flow=4.1e+04, val_loss flow=0, theta = [-3.056 -3.265  0.    -4.609  0.    -3.876], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.84, avg beta=4, loss prop od=8.2e+02, loss ntrips=0, total trips=[6.3e+04 6.4e+04 6.2e+04 7.6e+04 7.6e+04 7.6e+04], lambda eq=0.6, relative x=0.056, relative gap=0.026, train flow equilibrium loss=1.1e+04, time: 128.5
#
# Epoch: 110/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 110: train_loss=1.4e+04, val_loss=0, train_loss tt=0.0014, val_loss tt=0, train_loss flow=3.8e+04, val_loss flow=0, theta = [-3.056 -3.255  0.    -4.601  0.    -3.877], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.86, avg beta=4, loss prop od=9.1e+02, loss ntrips=0, total trips=[6.3e+04 6.5e+04 6.2e+04 7.6e+04 7.7e+04 7.7e+04], lambda eq=0.6, relative x=0.053, relative gap=0.024, train flow equilibrium loss=1.1e+04, time: 129.0
#
# Epoch: 120/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 120: train_loss=1.4e+04, val_loss=0, train_loss tt=0.0014, val_loss tt=0, train_loss flow=3.7e+04, val_loss flow=0, theta = [-3.057 -3.262  0.    -4.591  0.    -3.878], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.88, avg beta=4, loss prop od=1e+03, loss ntrips=0, total trips=[6.4e+04 6.5e+04 6.2e+04 7.7e+04 7.7e+04 7.7e+04], lambda eq=0.6, relative x=0.079, relative gap=0.023, train flow equilibrium loss=1.1e+04, time: 129.1
#
# Epoch: 130/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 130: train_loss=1.4e+04, val_loss=0, train_loss tt=0.0014, val_loss tt=0, train_loss flow=3.7e+04, val_loss flow=0, theta = [-3.058 -3.268  0.    -4.579  0.    -3.879], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.9, avg beta=4.1, loss prop od=1.1e+03, loss ntrips=0, total trips=[6.4e+04 6.5e+04 6.3e+04 7.7e+04 7.8e+04 7.8e+04], lambda eq=0.6, relative x=0.051, relative gap=0.022, train flow equilibrium loss=1e+04, time: 129.3
#
# Epoch: 140/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 140: train_loss=1.3e+04, val_loss=0, train_loss tt=0.0014, val_loss tt=0, train_loss flow=3.7e+04, val_loss flow=0, theta = [-3.059 -3.273  0.    -4.567  0.    -3.88 ], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.91, avg beta=4.1, loss prop od=1.2e+03, loss ntrips=0, total trips=[6.4e+04 6.5e+04 6.3e+04 7.8e+04 7.8e+04 7.8e+04], lambda eq=0.6, relative x=0.049, relative gap=0.021, train flow equilibrium loss=1e+04, time: 128.8
#
# Epoch: 150/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 150: train_loss=1.3e+04, val_loss=0, train_loss tt=0.0013, val_loss tt=0, train_loss flow=3.7e+04, val_loss flow=0, theta = [-3.059 -3.276  0.    -4.553  0.    -3.879], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.92, avg beta=4.1, loss prop od=1.2e+03, loss ntrips=0, total trips=[6.4e+04 6.5e+04 6.3e+04 7.8e+04 7.9e+04 7.9e+04], lambda eq=0.6, relative x=0.049, relative gap=0.021, train flow equilibrium loss=1e+04, time: 128.3
#
# Epoch: 160/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 160: train_loss=1.3e+04, val_loss=0, train_loss tt=0.0013, val_loss tt=0, train_loss flow=3.7e+04, val_loss flow=0, theta = [-3.06  -3.269  0.    -4.54   0.    -3.879], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.93, avg beta=4.1, loss prop od=1.3e+03, loss ntrips=0, total trips=[6.4e+04 6.5e+04 6.3e+04 7.8e+04 7.9e+04 7.9e+04], lambda eq=0.6, relative x=0.048, relative gap=0.02, train flow equilibrium loss=9.8e+03, time: 128.6
#
# Epoch: 163/300, n_periods: 6,  n_timepoints: 90, coverage t, x: [0.86 0.06]
# 163: train_loss=1.3e+04, val_loss=0, train_loss tt=0.0013, val_loss tt=0, train_loss flow=3.7e+04, val_loss flow=0, theta = [-3.06  -3.268  0.    -4.537  0.    -3.879], avg rr = 1.07, psc_factor = 0.0, avg theta fixed effect = -0.13, avg alpha=0.93, avg beta=4.1, loss prop od=1.3e+03, loss ntrips=0, total trips=[6.4e+04 6.6e+04 6.3e+04 7.8e+04 7.9e+04 7.9e+04], lambda eq=0.6, relative x=0.048, relative gap=0.02, train flow equilibrium loss=9.8e+03, time: 39.0
# /Users/pablo/opt/anaconda3/envs/pesuelogit/lib/python3.10/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.0, 0.0, 0.0)) for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# theta:
#               tt     tt_sd  median_inc  incidents  bus_stops  intersections  \
# 6-7   -3.030711 -2.743564         0.0  -4.678586        0.0      -3.790288
# 7-8   -3.047338 -3.014258         0.0  -4.587864        0.0      -4.009669
# 8-9   -3.046424 -3.184558         0.0  -4.659977        0.0      -3.914328
# 15-16 -3.111902 -3.102616         0.0  -4.466753        0.0      -3.807228
# 16-17 -3.064629 -3.691020         0.0  -4.481502        0.0      -3.872662
# 17-18 -3.056897 -3.871063         0.0  -4.346198        0.0      -3.878864
#
#        hour        rr
# 6-7       6  0.905254
# 7-8       7  0.989144
# 8-9       8  1.045343
# 15-16    15  0.997016
# 16-17    16  1.204394
# 17-18    17  1.266337
# alpha =  0.93, beta  =  4.10
# Avg abs diff of observed and estimated OD:  9.54
# Avg observed OD:  9.51
# MAPE link flows=18.9,MAPE travel times=5.4
# MSE link flows=3.7e+04, MSE travel times=0.0013,MSE equilibrium flows=1.5e+04
# runtime: 2106.9 [s]

# %% [markdown]
# ## Write predictions

# %%
predictions = pd.DataFrame({'link_key': list(fresno_network.links_keys) * Y_train.shape[0],
                            'observed_traveltime': Y_train[:, :, 0].numpy().flatten(),
                            'observed_flow': Y_train[:, :, 1].numpy().flatten()})

predictions['date'] = sorted(df[df.hour == 16].loc[df[df.hour == 16].year == 2019, 'date'])

# TODO: Write predictions for TVODLULPE model
for model in [lue,odlue,odlulpe]:

    predicted_flows = model.flows()
    predicted_traveltimes = model.traveltimes()

    predictions['predicted_traveltime_' + model.key] = np.tile(predicted_traveltimes, (Y_train.shape[0], 1)).flatten()
    predictions['predicted_flow_' + model.key] = np.tile(predicted_flows, (Y_train.shape[0], 1)).flatten()

predictions.to_csv(f"./output/tables/{datetime.now().strftime('%y%m%d%H%M%S')}_train_predictions_{'Fresno'}.csv", index=False)

# %% [markdown]
# ## Write estimation results

# %%
train_results_df, test_results_df \
    = map(lambda x: pd.concat([results.assign(model = model)[['model'] + list(results.columns)]
                               for model, results in x.items()],axis = 0), [train_results_dfs, test_results_dfs])

network_name = 'Fresno'

train_filename = f"{datetime.now().strftime('%y%m%d%H%M%S')}_train_results_{network_name}.csv"
test_filename = f"{datetime.now().strftime('%y%m%d%H%M%S')}_validation_results_{network_name}.csv"
train_results_df.to_csv(f"./output/tables/{train_filename}")
print(f'File {train_filename} was written')
test_results_df.to_csv(f"./output/tables/{test_filename}")
print(f'File {test_filename} was written')
# Out:
# File 230411001140_train_results_Fresno.csv was written
# File 230411001140_validation_results_Fresno.csv was written

# %% [markdown]
# ## Summary of models parameters

# %%
models = [lue,odlue,odlulpe, tvodlulpe]
results = pd.DataFrame({'parameter': [], 'model': []})

for model in models:
    results = pd.concat([results, pd.DataFrame(
        {'parameter': ['tt'] + features_Z +
                      ['rr'] +
                      ['fixed_effect_mean', 'fixed_effect_std',
                       'alpha_mean', 'alpha_std',
                       'beta_mean', 'beta_std',
                       'od_mean', 'od_std',],
         'values': list(np.mean(model.theta.numpy(),axis =0))  +
                   [float(model.get_parameters_estimates().eval('tt_sd/tt'))] +
                   [np.mean(model.fixed_effect),np.std(model.fixed_effect),
                    np.mean(model.alpha),np.std(model.alpha),
                    np.mean(model.beta),np.std(model.beta),
                    np.mean(model.q),np.std(model.q)]}).\
                             assign(model = model.key)
                             ])

# %%
results.pivot_table(index = ['parameter'], columns = 'model', values = 'values', sort=False).round(4)
# Out:
# model                  lue    odlue  odlulpe  tvodlulpe
# parameter
# tt                 -0.3569  -3.0786  -2.8586    -3.0597
# tt_sd               0.0000  -9.7975  -3.7984    -3.2678
# median_inc          0.0000   0.0000   0.0000     0.0000
# incidents           0.0000  -0.9494  -0.7533    -4.5368
# bus_stops           0.0000   0.0000   0.0000     0.0000
# intersections      -0.1391  -2.4912  -1.8976    -3.8788
# rr                  0.0000   3.1825   1.3288     1.0680
# fixed_effect_mean   0.0000   0.0000   0.0000    -0.1270
# fixed_effect_std    0.0000   0.0000   0.0000     2.0873
# alpha_mean          0.1500   0.1500   0.2793     0.9327
# alpha_std           0.0000   0.0000   0.5577     1.8342
# beta_mean           4.0000   4.0000   2.2681     4.1017
# beta_std            0.0000   0.0000   2.1659     2.5296
# od_mean             9.5074  17.3135  11.0771    10.2663
# od_std             41.5103  65.2017  39.5372    38.0548

# %% [markdown]
# ## Summary of models goodness of fit

# %%
models = [lue, odlue, odlulpe, tvodlulpe]
#models = [tvodlulpe]
results_losses = pd.DataFrame({})
loss_columns = ['loss_flow', 'loss_tt', 'loss_eq_flow', 'loss_total']

for i, model in enumerate(models):

    results_losses_model = model.split_results(train_results_dfs[model.key])[1].assign(model = model.key)
    results_losses_model = results_losses_model[results_losses_model.epoch == results_losses_model.epoch.max()].iloc[[0]]
    results_losses = pd.concat([results_losses, results_losses_model])

results_losses[loss_columns] = (results_losses[loss_columns]-1)*100

# %%
results_losses[['model'] + list(results_losses.columns)]
# Out:
#          model  epoch    loss_tt       loss_od  loss_theta  loss_flow  \
# 313        lue    312 -46.455964  1.000000e+00         NaN -24.862632
# 302      odlue    301 -95.519458  1.648504e+32         NaN -95.868550
# 127    odlulpe    127 -98.874199  4.880503e+31         NaN -97.575484
# 163  tvodlulpe    163 -98.798841  5.394558e+31         NaN -98.208276
#
#      loss_eq_flow  loss_eq_tt  loss_bpr  loss_ntrips  loss_prop_od  \
# 313    -98.148734         NaN       NaN          NaN  1.000000e+00
# 302    -96.291152         NaN       NaN          NaN  7.629741e+31
# 127    -95.929064         NaN       NaN          NaN  4.305892e+31
# 163    -97.030597         NaN       NaN          NaN  4.629988e+31
#
#      loss_total  relative_gap      model
# 313  -99.708552      0.017996        lue
# 302  -99.351286      0.017677      odlue
# 127  -99.105160      0.019969    odlulpe
# 163  -99.360271      0.019963  tvodlulpe

# %% [markdown]
# ## Plot of convergence toward true rr across models

# %%
train_estimates = {}
train_losses = {}

for model in models:
    train_estimates[model.key], train_losses[model.key] = model.split_results(results=train_results_dfs[model.key])

    train_estimates[model.key]['model'] = model.key

train_estimates_df = pd.concat(train_estimates.values())

train_estimates_df['rr'] = train_estimates_df['tt_sd']/train_estimates_df['tt']

estimates = train_estimates_df[['epoch','model','rr']].reset_index().drop('index',axis = 1)
estimates = estimates[estimates.epoch != 0]

fig, ax = plt.subplots(nrows=1, ncols=1)

g = sns.lineplot(data=estimates, x='epoch', hue='model', y='rr')

ax.set_ylabel('average reliability ratio')

plt.ylim(ymin=0)

plt.show()

# %% [markdown]
# ## Plot of reliability ratio by hour for all models

# %%
reliability_ratios = plot_rr_by_period_models(models, period_keys, period_feature='hour')
plt.show()
# Out:
# /Users/pablo/opt/anaconda3/envs/pesuelogit/lib/python3.10/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.0, 0.0, 0.0)) for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
reliability_ratios.groupby('model')[['rr']].mean().round(4)
# Out:
#                rr
# model
# lue        0.0000
# odlue      3.1825
# odlulpe    1.3288
# tvodlulpe  1.0679

# %% [markdown]
# ## Plot of total trips by hour for all models

# %%
total_trips = plot_total_trips_models(models = models, period_feature = 'hour', period_keys = period_keys,
                                      historic_od = fresno_network.q.flatten())
plt.show()
# Out:
# /Users/pablo/opt/anaconda3/envs/pesuelogit/lib/python3.10/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.0, 0.0, 0.0)) for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
total_trips.groupby('model')[['total_trips']].mean().round(1)
# Out:
#            total_trips
# model
# lue            66266.3
# odlue         120674.8
# odlulpe        77207.3
# tvodlulpe      71556.1

# %%
total_trips.groupby('model')[['total_trips']].sum().round(1)
# Out:
#            total_trips
# model
# lue            66266.3
# odlue         120674.8
# odlulpe        77207.3
# tvodlulpe     429336.7

# %% [markdown]
# ## Global runtime

# %%
print(f'runtime: {time.time()-t0_global:0.1f} [s]')
# Out:
# runtime: 6046.6 [s]
